# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.22.0

# %%
csv_fp = 'csv_sample/ex1.csv'
df = pd.read_csv(csv_fp)
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df = pd.read_table(csv_fp, sep=',')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names=['aa', 'bb', 'cc', 'dd', 'ee']
df = pd.read_csv(csv_fp, names=names)
df
# Out:
#   aa  bb  cc  dd       ee
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
# Write data to text files.
import sys
df.to_csv(sys.stdout, sep=',')
# Out:
# ,aa,bb,cc,dd,ee
# 0,a,b,c,d,message
# 1,1,2,3,4,hello
# 2,5,6,7,8,world
# 3,9,10,11,12,foo

# %%
df.to_csv(sys.stdout, sep=',', index=False)
# Out:
# aa,bb,cc,dd,ee
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
# Interacting with web apis.
# 5 day weather forecast
# https://openweathermap.org/forecast5
city='melbourne'
country='aus'
appid='f29164c280fc240f3a98804944423382'
url='http://api.openweathermap.org/data/2.5/forecast?q={},{}&units=metric&appid={}'.format(city, country, appid)

import requests
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
weather_data = resp.json()
weather_data
# Out:
# {'city': {'coord': {'lat': -37.8143, 'lon': 144.9632},
#   'country': 'AU',
#   'id': 2158177,
#   'name': 'Melbourne',
#   'population': 15000},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 24},
#    'dt': 1549411200,
#    'dt_txt': '2019-02-06 00:00:00',
#    'main': {'grnd_level': 1010.04,
#     'humidity': 72,
#     'pressure': 1010.04,
#     'sea_level': 1027.45,
#     'temp': 30.62,
#     'temp_kf': 4.38,
#     'temp_max': 30.62,
#     'temp_min': 26.23},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 59.0002, 'speed': 1.22}},
#   {'clouds': {'all': 32},
#    'dt': 1549422000,
#    'dt_txt': '2019-02-06 03:00:00',
#    'main': {'grnd_level': 1008.38,
#     'humidity': 67,
#     'pressure': 1008.38,
#     'sea_level': 1025.67,
#     'temp': 31.88,
#     'temp_kf': 3.29,
#     'temp_max': 31.88,
#     'temp_min': 28.6},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 21.0046, 'speed': 2.25}},
#   {'clouds': {'all': 44},
#    'dt': 1549432800,
#    'dt_txt': '2019-02-06 06:00:00',
#    'main': {'grnd_level': 1006.44,
#     'humidity': 64,
#     'pressure': 1006.44,
#     'sea_level': 1023.72,
#     'temp': 30.89,
#     'temp_kf': 2.19,
#     'temp_max': 30.89,
#     'temp_min': 28.7},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 28.0031, 'speed': 1.76}},
#   {'clouds': {'all': 44},
#    'dt': 1549443600,
#    'dt_txt': '2019-02-06 09:00:00',
#    'main': {'grnd_level': 1007.57,
#     'humidity': 100,
#     'pressure': 1007.57,
#     'sea_level': 1024.82,
#     'temp': 22.13,
#     'temp_kf': 1.1,
#     'temp_max': 22.13,
#     'temp_min': 21.03},
#    'rain': {'3h': 4.0775},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'moderate rain',
#      'icon': '10d',
#      'id': 501,
#      'main': 'Rain'}],
#    'wind': {'deg': 293.01, 'speed': 1.35}},
#   {'clouds': {'all': 68},
#    'dt': 1549454400,
#    'dt_txt': '2019-02-06 12:00:00',
#    'main': {'grnd_level': 1008.55,
#     'humidity': 100,
#     'pressure': 1008.55,
#     'sea_level': 1026,
#     'temp': 18.96,
#     'temp_kf': 0,
#     'temp_max': 18.96,
#     'temp_min': 18.96},
#    'rain': {'3h': 3.9},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'moderate rain',
#      'icon': '10n',
#      'id': 501,
#      'main': 'Rain'}],
#    'wind': {'deg': 115.503, 'speed': 0.66}},
#   {'clouds': {'all': 68},
#    'dt': 1549465200,
#    'dt_txt': '2019-02-06 15:00:00',
#    'main': {'grnd_level': 1007.07,
#     'humidity': 100,
#     'pressure': 1007.07,
#     'sea_level': 1024.54,
#     'temp': 19.02,
#     'temp_kf': 0,
#     'temp_max': 19.02,
#     'temp_min': 19.02},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 298.002, 'speed': 1.1}},
#   {'clouds': {'all': 92},
#    'dt': 1549476000,
#    'dt_txt': '2019-02-06 18:00:00',
#    'main': {'grnd_level': 1007.56,
#     'humidity': 100,
#     'pressure': 1007.56,
#     'sea_level': 1025.03,
#     'temp': 19.13,
#     'temp_kf': 0,
#     'temp_max': 19.13,
#     'temp_min': 19.13},
#    'rain': {'3h': 9.725},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'moderate rain',
#      'icon': '10n',
#      'id': 501,
#      'main': 'Rain'}],
#    'wind': {'deg': 325.5, 'speed': 1.06}},
#   {'clouds': {'all': 80},
#    'dt': 1549486800,
#    'dt_txt': '2019-02-06 21:00:00',
#    'main': {'grnd_level': 1007.51,
#     'humidity': 100,
#     'pressure': 1007.51,
#     'sea_level': 1025.14,
#     'temp': 19.18,
#     'temp_kf': 0,
#     'temp_max': 19.18,
#     'temp_min': 19.18},
#    'rain': {'3h': 16.03},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'heavy intensity rain',
#      'icon': '10d',
#      'id': 502,
#      'main': 'Rain'}],
#    'wind': {'deg': 14.0005, 'speed': 1.96}},
#   {'clouds': {'all': 92},
#    'dt': 1549497600,
#    'dt_txt': '2019-02-07 00:00:00',
#    'main': {'grnd_level': 1008.14,
#     'humidity': 98,
#     'pressure': 1008.14,
#     'sea_level': 1025.63,
#     'temp': 21.51,
#     'temp_kf': 0,
#     'temp_max': 21.51,
#     'temp_min': 21.51},
#    'rain': {'3h': 0.575},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 329.509, 'speed': 1.68}},
#   {'clouds': {'all': 88},
#    'dt': 1549508400,
#    'dt_txt': '2019-02-07 03:00:00',
#    'main': {'grnd_level': 1007.36,
#     'humidity': 100,
#     'pressure': 1007.36,
#     'sea_level': 1024.65,
#     'temp': 20.68,
#     'temp_kf': 0,
#     'temp_max': 20.68,
#     'temp_min': 20.68},
#    'rain': {'3h': 1.9},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 298, 'speed': 1.33}},
#   {'clouds': {'all': 76},
#    'dt': 1549519200,
#    'dt_txt': '2019-02-07 06:00:00',
#    'main': {'grnd_level': 1005.7,
#     'humidity': 95,
#     'pressure': 1005.7,
#     'sea_level': 1023.05,
#     'temp': 22.98,
#     'temp_kf': 0,
#     'temp_max': 22.98,
#     'temp_min': 22.98},
#    'rain': {'3h': 0.039999999999999},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 1.50174, 'speed': 1.37}},
#   {'clouds': {'all': 48},
#    'dt': 1549530000,
#    'dt_txt': '2019-02-07 09:00:00',
#    'main': {'grnd_level': 1005.71,
#     'humidity': 99,
#     'pressure': 1005.71,
#     'sea_level': 1022.93,
#     'temp': 20.86,
#     'temp_kf': 0,
#     'temp_max': 20.86,
#     'temp_min': 20.86},
#    'rain': {'3h': 1.07},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 328.505, 'speed': 1.21}},
#   {'clouds': {'all': 0},
#    'dt': 1549540800,
#    'dt_txt': '2019-02-07 12:00:00',
#    'main': {'grnd_level': 1006.28,
#     'humidity': 95,
#     'pressure': 1006.28,
#     'sea_level': 1023.87,
#     'temp': 18.43,
#     'temp_kf': 0,
#     'temp_max': 18.43,
#     'temp_min': 18.43},
#    'rain': {'3h': 0.020000000000003},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 301.003, 'speed': 0.52}},
#   {'clouds': {'all': 56},
#    'dt': 1549551600,
#    'dt_txt': '2019-02-07 15:00:00',
#    'main': {'grnd_level': 1006.05,
#     'humidity': 98,
#     'pressure': 1006.05,
#     'sea_level': 1023.52,
#     'temp': 17.12,
#     'temp_kf': 0,
#     'temp_max': 17.12,
#     'temp_min': 17.12},
#    'rain': {'3h': 0.009999999999998},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 186.002, 'speed': 1.18}},
#   {'clouds': {'all': 92},
#    'dt': 1549562400,
#    'dt_txt': '2019-02-07 18:00:00',
#    'main': {'grnd_level': 1005.67,
#     'humidity': 100,
#     'pressure': 1005.67,
#     'sea_level': 1023.21,
#     'temp': 17.66,
#     'temp_kf': 0,
#     'temp_max': 17.66,
#     'temp_min': 17.66},
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 224.002, 'speed': 1.36}},
#   {'clouds': {'all': 68},
#    'dt': 1549573200,
#    'dt_txt': '2019-02-07 21:00:00',
#    'main': {'grnd_level': 1006.49,
#     'humidity': 100,
#     'pressure': 1006.49,
#     'sea_level': 1023.87,
#     'temp': 16.5,
#     'temp_kf': 0,
#     'temp_max': 16.5,
#     'temp_min': 16.5},
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 248.501, 'speed': 1.76}},
#   {'clouds': {'all': 76},
#    'dt': 1549584000,
#    'dt_txt': '2019-02-08 00:00:00',
#    'main': {'grnd_level': 1006.76,
#     'humidity': 100,
#     'pressure': 1006.76,
#     'sea_level': 1024.1,
#     'temp': 17.43,
#     'temp_kf': 0,
#     'temp_max': 17.43,
#     'temp_min': 17.43},
#    'rain': {'3h': 0.07},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 252.002, 'speed': 1.47}},
#   {'clouds': {'all': 88},
#    'dt': 1549594800,
#    'dt_txt': '2019-02-08 03:00:00',
#    'main': {'grnd_level': 1006.04,
#     'humidity': 97,
#     'pressure': 1006.04,
#     'sea_level': 1023.29,
#     'temp': 18.18,
#     'temp_kf': 0,
#     'temp_max': 18.18,
#     'temp_min': 18.18},
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 208.003, 'speed': 2.16}},
#   {'clouds': {'all': 64},
#    'dt': 1549605600,
#    'dt_txt': '2019-02-08 06:00:00',
#    'main': {'grnd_level': 1005.26,
#     'humidity': 95,
#     'pressure': 1005.26,
#     'sea_level': 1022.46,
#     'temp': 17.49,
#     'temp_kf': 0,
#     'temp_max': 17.49,
#     'temp_min': 17.49},
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 201.001, 'speed': 1.76}},
#   {'clouds': {'all': 56},
#    'dt': 1549616400,
#    'dt_txt': '2019-02-08 09:00:00',
#    'main': {'grnd_level': 1004.73,
#     'humidity': 95,
#     'pressure': 1004.73,
#     'sea_level': 1022.11,
#     'temp': 16.83,
#     'temp_kf': 0,
#     'temp_max': 16.83,
#     'temp_min': 16.83},
#    'rain': {'3h': 0.050000000000004},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 209.002, 'speed': 1.06}},
#   {'clouds': {'all': 100},
#    'dt': 1549627200,
#    'dt_txt': '2019-02-08 12:00:00',
#    'main': {'grnd_level': 1005.58,
#     'humidity': 100,
#     'pressure': 1005.58,
#     'sea_level': 1022.98,
#     'temp': 15.28,
#     'temp_kf': 0,
#     'temp_max': 15.28,
#     'temp_min': 15.28},
#    'rain': {'3h': 1.08},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 220.5, 'speed': 1.46}},
#   {'clouds': {'all': 0},
#    'dt': 1549638000,
#    'dt_txt': '2019-02-08 15:00:00',
#    'main': {'grnd_level': 1004.23,
#     'humidity': 100,
#     'pressure': 1004.23,
#     'sea_level': 1021.81,
#     'temp': 13.5,
#     'temp_kf': 0,
#     'temp_max': 13.5,
#     'temp_min': 13.5},
#    'rain': {'3h': 0.019999999999996},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 264.002, 'speed': 2}},
#   {'clouds': {'all': 0},
#    'dt': 1549648800,
#    'dt_txt': '2019-02-08 18:00:00',
#    'main': {'grnd_level': 1003.42,
#     'humidity': 100,
#     'pressure': 1003.42,
#     'sea_level': 1021.04,
#     'temp': 11.9,
#     'temp_kf': 0,
#     'temp_max': 11.9,
#     'temp_min': 11.9},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 280.5, 'speed': 2.11}},
#   {'clouds': {'all': 0},
#    'dt': 1549659600,
#    'dt_txt': '2019-02-08 21:00:00',
#    'main': {'grnd_level': 1003.72,
#     'humidity': 100,
#     'pressure': 1003.72,
#     'sea_level': 1021.25,
#     'temp': 11.98,
#     'temp_kf': 0,
#     'temp_max': 11.98,
#     'temp_min': 11.98},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 292, 'speed': 2.22}},
#   {'clouds': {'all': 44},
#    'dt': 1549670400,
#    'dt_txt': '2019-02-09 00:00:00',
#    'main': {'grnd_level': 1004.35,
#     'humidity': 92,
#     'pressure': 1004.35,
#     'sea_level': 1021.78,
#     'temp': 16.31,
#     'temp_kf': 0,
#     'temp_max': 16.31,
#     'temp_min': 16.31},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 279.005, 'speed': 2.36}},
#   {'clouds': {'all': 80},
#    'dt': 1549681200,
#    'dt_txt': '2019-02-09 03:00:00',
#    'main': {'grnd_level': 1003.59,
#     'humidity': 76,
#     'pressure': 1003.59,
#     'sea_level': 1020.97,
#     'temp': 19.33,
#     'temp_kf': 0,
#     'temp_max': 19.33,
#     'temp_min': 19.33},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 261.503, 'speed': 2.95}},
#   {'clouds': {'all': 100},
#    'dt': 1549692000,
#    'dt_txt': '2019-02-09 06:00:00',
#    'main': {'grnd_level': 1003.48,
#     'humidity': 75,
#     'pressure': 1003.48,
#     'sea_level': 1020.88,
#     'temp': 19.06,
#     'temp_kf': 0,
#     'temp_max': 19.06,
#     'temp_min': 19.06},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 247.501, 'speed': 3.16}},
#   {'clouds': {'all': 100},
#    'dt': 1549702800,
#    'dt_txt': '2019-02-09 09:00:00',
#    'main': {'grnd_level': 1004.72,
#     'humidity': 73,
#     'pressure': 1004.72,
#     'sea_level': 1022.11,
#     'temp': 18.46,
#     'temp_kf': 0,
#     'temp_max': 18.46,
#     'temp_min': 18.46},
#    'rain': {'3h': 0.010000000000005},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 246.501, 'speed': 2.36}},
#   {'clouds': {'all': 36},
#    'dt': 1549713600,
#    'dt_txt': '2019-02-09 12:00:00',
#    'main': {'grnd_level': 1006.54,
#     'humidity': 77,
#     'pressure': 1006.54,
#     'sea_level': 1023.99,
#     'temp': 17.16,
#     'temp_kf': 0,
#     'temp_max': 17.16,
#     'temp_min': 17.16},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 260.503, 'speed': 1.96}},
#   {'clouds': {'all': 0},
#    'dt': 1549724400,
#    'dt_txt': '2019-02-09 15:00:00',
#    'main': {'grnd_level': 1006.73,
#     'humidity': 92,
#     'pressure': 1006.73,
#     'sea_level': 1024.27,
#     'temp': 14.27,
#     'temp_kf': 0,
#     'temp_max': 14.27,
#     'temp_min': 14.27},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 288.002, 'speed': 1.52}},
#   {'clouds': {'all': 12},
#    'dt': 1549735200,
#    'dt_txt': '2019-02-09 18:00:00',
#    'main': {'grnd_level': 1006.55,
#     'humidity': 95,
#     'pressure': 1006.55,
#     'sea_level': 1024.21,
#     'temp': 13.18,
#     'temp_kf': 0,
#     'temp_max': 13.18,
#     'temp_min': 13.18},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 314.001, 'speed': 1.76}},
#   {'clouds': {'all': 0},
#    'dt': 1549746000,
#    'dt_txt': '2019-02-09 21:00:00',
#    'main': {'grnd_level': 1007.65,
#     'humidity': 93,
#     'pressure': 1007.65,
#     'sea_level': 1025.34,
#     'temp': 14.64,
#     'temp_kf': 0,
#     'temp_max': 14.64,
#     'temp_min': 14.64},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 303.002, 'speed': 1.97}},
#   {'clouds': {'all': 0},
#    'dt': 1549756800,
#    'dt_txt': '2019-02-10 00:00:00',
#    'main': {'grnd_level': 1008.4,
#     'humidity': 79,
#     'pressure': 1008.4,
#     'sea_level': 1025.82,
#     'temp': 19.51,
#     'temp_kf': 0,
#     'temp_max': 19.51,
#     'temp_min': 19.51},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 281.5, 'speed': 1.65}},
#   {'clouds': {'all': 24},
#    'dt': 1549767600,
#    'dt_txt': '2019-02-10 03:00:00',
#    'main': {'grnd_level': 1007.33,
#     'humidity': 73,
#     'pressure': 1007.33,
#     'sea_level': 1024.58,
#     'temp': 21.99,
#     'temp_kf': 0,
#     'temp_max': 21.99,
#     'temp_min': 21.99},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 251.001, 'speed': 1.56}},
#   {'clouds': {'all': 24},
#    'dt': 1549778400,
#    'dt_txt': '2019-02-10 06:00:00',
#    'main': {'grnd_level': 1006.02,
#     'humidity': 72,
#     'pressure': 1006.02,
#     'sea_level': 1023.32,
#     'temp': 22.87,
#     'temp_kf': 0,
#     'temp_max': 22.87,
#     'temp_min': 22.87},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 232.001, 'speed': 1.42}},
#   {'clouds': {'all': 44},
#    'dt': 1549789200,
#    'dt_txt': '2019-02-10 09:00:00',
#    'main': {'grnd_level': 1005.78,
#     'humidity': 75,
#     'pressure': 1005.78,
#     'sea_level': 1023.15,
#     'temp': 21.07,
#     'temp_kf': 0,
#     'temp_max': 21.07,
#     'temp_min': 21.07},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 227.501, 'speed': 0.96}},
#   {'clouds': {'all': 20},
#    'dt': 1549800000,
#    'dt_txt': '2019-02-10 12:00:00',
#    'main': {'grnd_level': 1005.95,
#     'humidity': 92,
#     'pressure': 1005.95,
#     'sea_level': 1023.49,
#     'temp': 17.57,
#     'temp_kf': 0,
#     'temp_max': 17.57,
#     'temp_min': 17.57},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 157.001, 'speed': 1.06}},
#   {'clouds': {'all': 8},
#    'dt': 1549810800,
#    'dt_txt': '2019-02-10 15:00:00',
#    'main': {'grnd_level': 1004.26,
#     'humidity': 100,
#     'pressure': 1004.26,
#     'sea_level': 1021.86,
#     'temp': 15.07,
#     'temp_kf': 0,
#     'temp_max': 15.07,
#     'temp_min': 15.07},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 80.0006, 'speed': 1.16}},
#   {'clouds': {'all': 0},
#    'dt': 1549821600,
#    'dt_txt': '2019-02-10 18:00:00',
#    'main': {'grnd_level': 1002.65,
#     'humidity': 100,
#     'pressure': 1002.65,
#     'sea_level': 1020.15,
#     'temp': 13.88,
#     'temp_kf': 0,
#     'temp_max': 13.88,
#     'temp_min': 13.88},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 36.0037, 'speed': 1.26}},
#   {'clouds': {'all': 0},
#    'dt': 1549832400,
#    'dt_txt': '2019-02-10 21:00:00',
#    'main': {'grnd_level': 1002.72,
#     'humidity': 90,
#     'pressure': 1002.72,
#     'sea_level': 1020.15,
#     'temp': 17.64,
#     'temp_kf': 0,
#     'temp_max': 17.64,
#     'temp_min': 17.64},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 347.502, 'speed': 2.55}}],
#  'message': 0.0059}

# %%
df = pd.DataFrame(weather_data['list'])
df
# Out:
#           clouds          dt               dt_txt  \
# 0   {'all': 100}  1548514800  2019-01-26 15:00:00
# 1    {'all': 92}  1548525600  2019-01-26 18:00:00
# 2    {'all': 80}  1548536400  2019-01-26 21:00:00
# 3    {'all': 92}  1548547200  2019-01-27 00:00:00
# 4    {'all': 80}  1548558000  2019-01-27 03:00:00
# 5    {'all': 12}  1548568800  2019-01-27 06:00:00
# 6    {'all': 64}  1548579600  2019-01-27 09:00:00
# 7    {'all': 36}  1548590400  2019-01-27 12:00:00
# 8    {'all': 32}  1548601200  2019-01-27 15:00:00
# 9    {'all': 24}  1548612000  2019-01-27 18:00:00
# 10    {'all': 0}  1548622800  2019-01-27 21:00:00
# 11    {'all': 0}  1548633600  2019-01-28 00:00:00
# 12    {'all': 0}  1548644400  2019-01-28 03:00:00
# 13    {'all': 0}  1548655200  2019-01-28 06:00:00
# 14    {'all': 0}  1548666000  2019-01-28 09:00:00
# 15    {'all': 0}  1548676800  2019-01-28 12:00:00
# 16    {'all': 0}  1548687600  2019-01-28 15:00:00
# 17    {'all': 0}  1548698400  2019-01-28 18:00:00
# 18    {'all': 0}  1548709200  2019-01-28 21:00:00
# 19    {'all': 0}  1548720000  2019-01-29 00:00:00
# 20    {'all': 0}  1548730800  2019-01-29 03:00:00
# 21   {'all': 12}  1548741600  2019-01-29 06:00:00
# 22   {'all': 44}  1548752400  2019-01-29 09:00:00
# 23   {'all': 36}  1548763200  2019-01-29 12:00:00
# 24    {'all': 0}  1548774000  2019-01-29 15:00:00
# 25   {'all': 80}  1548784800  2019-01-29 18:00:00
# 26   {'all': 76}  1548795600  2019-01-29 21:00:00
# 27   {'all': 92}  1548806400  2019-01-30 00:00:00
# 28   {'all': 88}  1548817200  2019-01-30 03:00:00
# 29   {'all': 32}  1548828000  2019-01-30 06:00:00
# 30   {'all': 64}  1548838800  2019-01-30 09:00:00
# 31   {'all': 32}  1548849600  2019-01-30 12:00:00
# 32    {'all': 0}  1548860400  2019-01-30 15:00:00
# 33   {'all': 44}  1548871200  2019-01-30 18:00:00
# 34  {'all': 100}  1548882000  2019-01-30 21:00:00
# 35   {'all': 48}  1548892800  2019-01-31 00:00:00
# 36    {'all': 8}  1548903600  2019-01-31 03:00:00
# 37    {'all': 0}  1548914400  2019-01-31 06:00:00
# 38    {'all': 0}  1548925200  2019-01-31 09:00:00
# 39    {'all': 0}  1548936000  2019-01-31 12:00:00
#
#                                                  main  \
# 0   {'temp': 15.24, 'temp_min': 15.24, 'temp_max':...
# 1   {'temp': 14.71, 'temp_min': 14.71, 'temp_max':...
# 2   {'temp': 16.14, 'temp_min': 16.14, 'temp_max':...
# 3   {'temp': 19.15, 'temp_min': 19.15, 'temp_max':...
# 4   {'temp': 21.26, 'temp_min': 21.26, 'temp_max':...
# 5   {'temp': 24.34, 'temp_min': 24.34, 'temp_max':...
# 6   {'temp': 22.86, 'temp_min': 22.86, 'temp_max':...
# 7   {'temp': 19.49, 'temp_min': 19.49, 'temp_max':...
# 8   {'temp': 17.12, 'temp_min': 17.12, 'temp_max':...
# 9   {'temp': 14.91, 'temp_min': 14.91, 'temp_max':...
# 10  {'temp': 17.22, 'temp_min': 17.22, 'temp_max':...
# 11  {'temp': 24.36, 'temp_min': 24.36, 'temp_max':...
# 12  {'temp': 28.11, 'temp_min': 28.11, 'temp_max':...
# 13  {'temp': 29.49, 'temp_min': 29.49, 'temp_max':...
# 14  {'temp': 27.29, 'temp_min': 27.29, 'temp_max':...
# 15  {'temp': 24.05, 'temp_min': 24.05, 'temp_max':...
# 16  {'temp': 21.83, 'temp_min': 21.83, 'temp_max':...
# 17  {'temp': 19.85, 'temp_min': 19.85, 'temp_max':...
# 18  {'temp': 20.46, 'temp_min': 20.46, 'temp_max':...
# 19  {'temp': 26.61, 'temp_min': 26.61, 'temp_max':...
# 20  {'temp': 29.84, 'temp_min': 29.84, 'temp_max':...
# 21  {'temp': 31.38, 'temp_min': 31.38, 'temp_max':...
# 22  {'temp': 29, 'temp_min': 29, 'temp_max': 29, '...
# 23  {'temp': 26.08, 'temp_min': 26.08, 'temp_max':...
# 24  {'temp': 23.33, 'temp_min': 23.33, 'temp_max':...
# 25  {'temp': 22.44, 'temp_min': 22.44, 'temp_max':...
# 26  {'temp': 22.22, 'temp_min': 22.22, 'temp_max':...
# 27  {'temp': 20.15, 'temp_min': 20.15, 'temp_max':...
# 28  {'temp': 20.1, 'temp_min': 20.1, 'temp_max': 2...
# 29  {'temp': 24.23, 'temp_min': 24.23, 'temp_max':...
# 30  {'temp': 23.91, 'temp_min': 23.91, 'temp_max':...
# 31  {'temp': 21.02, 'temp_min': 21.02, 'temp_max':...
# 32  {'temp': 21, 'temp_min': 21, 'temp_max': 21, '...
# 33  {'temp': 17.93, 'temp_min': 17.93, 'temp_max':...
# 34  {'temp': 17.55, 'temp_min': 17.55, 'temp_max':...
# 35  {'temp': 18.53, 'temp_min': 18.53, 'temp_max':...
# 36  {'temp': 20.14, 'temp_min': 20.14, 'temp_max':...
# 37  {'temp': 19.44, 'temp_min': 19.44, 'temp_max':...
# 38  {'temp': 16.75, 'temp_min': 16.75, 'temp_max':...
# 39  {'temp': 14.7, 'temp_min': 14.7, 'temp_max': 1...
#
#                           rain           sys  \
# 0                 {'3h': 0.42}  {'pod': 'n'}
# 1                {'3h': 0.155}  {'pod': 'n'}
# 2                           {}  {'pod': 'd'}
# 3                           {}  {'pod': 'd'}
# 4                           {}  {'pod': 'd'}
# 5                           {}  {'pod': 'd'}
# 6                           {}  {'pod': 'd'}
# 7                           {}  {'pod': 'n'}
# 8                           {}  {'pod': 'n'}
# 9                           {}  {'pod': 'n'}
# 10                          {}  {'pod': 'd'}
# 11                          {}  {'pod': 'd'}
# 12                          {}  {'pod': 'd'}
# 13                          {}  {'pod': 'd'}
# 14                          {}  {'pod': 'd'}
# 15                          {}  {'pod': 'n'}
# 16                          {}  {'pod': 'n'}
# 17                          {}  {'pod': 'n'}
# 18                          {}  {'pod': 'd'}
# 19                          {}  {'pod': 'd'}
# 20                          {}  {'pod': 'd'}
# 21                          {}  {'pod': 'd'}
# 22               {'3h': 0.055}  {'pod': 'd'}
# 23                          {}  {'pod': 'n'}
# 24                          {}  {'pod': 'n'}
# 25                {'3h': 0.09}  {'pod': 'n'}
# 26                {'3h': 0.12}  {'pod': 'd'}
# 27                {'3h': 4.04}  {'pod': 'd'}
# 28                 {'3h': 5.3}  {'pod': 'd'}
# 29  {'3h': 0.0099999999999998}  {'pod': 'd'}
# 30                          {}  {'pod': 'd'}
# 31               {'3h': 0.335}  {'pod': 'n'}
# 32               {'3h': 0.025}  {'pod': 'n'}
# 33                          {}  {'pod': 'n'}
# 34              {'3h': 0.1875}  {'pod': 'd'}
# 35              {'3h': 0.0625}  {'pod': 'd'}
# 36                          {}  {'pod': 'd'}
# 37                          {}  {'pod': 'd'}
# 38                          {}  {'pod': 'd'}
# 39                          {}  {'pod': 'n'}
#
#                                               weather  \
# 0   [{'id': 500, 'main': 'Rain', 'description': 'l...
# 1   [{'id': 500, 'main': 'Rain', 'description': 'l...
# 2   [{'id': 803, 'main': 'Clouds', 'description': ...
# 3   [{'id': 804, 'main': 'Clouds', 'description': ...
# 4   [{'id': 803, 'main': 'Clouds', 'description': ...
# 5   [{'id': 801, 'main': 'Clouds', 'description': ...
# 6   [{'id': 803, 'main': 'Clouds', 'description': ...
# 7   [{'id': 802, 'main': 'Clouds', 'description': ...
# 8   [{'id': 802, 'main': 'Clouds', 'description': ...
# 9   [{'id': 801, 'main': 'Clouds', 'description': ...
# 10  [{'id': 800, 'main': 'Clear', 'description': '...
# 11  [{'id': 800, 'main': 'Clear', 'description': '...
# 12  [{'id': 800, 'main': 'Clear', 'description': '...
# 13  [{'id': 800, 'main': 'Clear', 'description': '...
# 14  [{'id': 800, 'main': 'Clear', 'description': '...
# 15  [{'id': 800, 'main': 'Clear', 'description': '...
# 16  [{'id': 800, 'main': 'Clear', 'description': '...
# 17  [{'id': 800, 'main': 'Clear', 'description': '...
# 18  [{'id': 800, 'main': 'Clear', 'description': '...
# 19  [{'id': 800, 'main': 'Clear', 'description': '...
# 20  [{'id': 800, 'main': 'Clear', 'description': '...
# 21  [{'id': 801, 'main': 'Clouds', 'description': ...
# 22  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 23  [{'id': 802, 'main': 'Clouds', 'description': ...
# 24  [{'id': 800, 'main': 'Clear', 'description': '...
# 25  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 26  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 27  [{'id': 501, 'main': 'Rain', 'description': 'm...
# 28  [{'id': 501, 'main': 'Rain', 'description': 'm...
# 29  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 30  [{'id': 803, 'main': 'Clouds', 'description': ...
# 31  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 32  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 33  [{'id': 802, 'main': 'Clouds', 'description': ...
# 34  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 35  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 36  [{'id': 800, 'main': 'Clear', 'description': '...
# 37  [{'id': 800, 'main': 'Clear', 'description': '...
# 38  [{'id': 800, 'main': 'Clear', 'description': '...
# 39  [{'id': 800, 'main': 'Clear', 'description': '...
#
#                                   wind
# 0      {'speed': 1.96, 'deg': 196.501}
# 1       {'speed': 1.4, 'deg': 202.002}
# 2      {'speed': 1.57, 'deg': 250.501}
# 3      {'speed': 1.62, 'deg': 278.001}
# 4      {'speed': 1.54, 'deg': 305.004}
# 5        {'speed': 1.33, 'deg': 294.5}
# 6      {'speed': 1.81, 'deg': 198.502}
# 7      {'speed': 1.82, 'deg': 156.003}
# 8        {'speed': 1.62, 'deg': 125.5}
# 9      {'speed': 0.77, 'deg': 140.504}
# 10     {'speed': 1.32, 'deg': 32.0095}
# 11     {'speed': 1.41, 'deg': 343.004}
# 12     {'speed': 2.11, 'deg': 329.504}
# 13     {'speed': 2.31, 'deg': 325.506}
# 14     {'speed': 2.35, 'deg': 345.002}
# 15     {'speed': 2.87, 'deg': 7.50085}
# 16     {'speed': 2.96, 'deg': 12.0045}
# 17      {'speed': 2.61, 'deg': 6.5007}
# 18     {'speed': 2.76, 'deg': 3.00195}
# 19       {'speed': 2.42, 'deg': 358.5}
# 20         {'speed': 2.29, 'deg': 351}
# 21     {'speed': 2.23, 'deg': 340.503}
# 22         {'speed': 1.35, 'deg': 321}
# 23     {'speed': 1.52, 'deg': 348.004}
# 24     {'speed': 2.22, 'deg': 4.00217}
# 25     {'speed': 3.57, 'deg': 11.0005}
# 26  {'speed': 3.43, 'deg': 0.00140381}
# 27     {'speed': 3.37, 'deg': 4.50439}
# 28     {'speed': 3.37, 'deg': 353.501}
# 29     {'speed': 3.51, 'deg': 348.508}
# 30     {'speed': 3.83, 'deg': 353.503}
# 31     {'speed': 4.56, 'deg': 351.003}
# 32       {'speed': 2.66, 'deg': 320.5}
# 33     {'speed': 2.01, 'deg': 193.001}
# 34     {'speed': 1.97, 'deg': 192.006}
# 35     {'speed': 2.22, 'deg': 201.002}
# 36         {'speed': 2.85, 'deg': 195}
# 37       {'speed': 3.31, 'deg': 193.5}
# 38     {'speed': 3.05, 'deg': 185.005}
# 39     {'speed': 2.32, 'deg': 166.003}

# %%
abstracted_data = [
    (weather['dt_txt'], weather['main']['temp']) 
    for weather in weather_data['list']]

df = pd.DataFrame(abstracted_data)
df
# Out:
#                       0      1
# 0   2019-02-06 00:00:00  30.62
# 1   2019-02-06 03:00:00  31.88
# 2   2019-02-06 06:00:00  30.89
# 3   2019-02-06 09:00:00  22.13
# 4   2019-02-06 12:00:00  18.96
# 5   2019-02-06 15:00:00  19.02
# 6   2019-02-06 18:00:00  19.13
# 7   2019-02-06 21:00:00  19.18
# 8   2019-02-07 00:00:00  21.51
# 9   2019-02-07 03:00:00  20.68
# 10  2019-02-07 06:00:00  22.98
# 11  2019-02-07 09:00:00  20.86
# 12  2019-02-07 12:00:00  18.43
# 13  2019-02-07 15:00:00  17.12
# 14  2019-02-07 18:00:00  17.66
# 15  2019-02-07 21:00:00  16.50
# 16  2019-02-08 00:00:00  17.43
# 17  2019-02-08 03:00:00  18.18
# 18  2019-02-08 06:00:00  17.49
# 19  2019-02-08 09:00:00  16.83
# 20  2019-02-08 12:00:00  15.28
# 21  2019-02-08 15:00:00  13.50
# 22  2019-02-08 18:00:00  11.90
# 23  2019-02-08 21:00:00  11.98
# 24  2019-02-09 00:00:00  16.31
# 25  2019-02-09 03:00:00  19.33
# 26  2019-02-09 06:00:00  19.06
# 27  2019-02-09 09:00:00  18.46
# 28  2019-02-09 12:00:00  17.16
# 29  2019-02-09 15:00:00  14.27
# 30  2019-02-09 18:00:00  13.18
# 31  2019-02-09 21:00:00  14.64
# 32  2019-02-10 00:00:00  19.51
# 33  2019-02-10 03:00:00  21.99
# 34  2019-02-10 06:00:00  22.87
# 35  2019-02-10 09:00:00  21.07
# 36  2019-02-10 12:00:00  17.57
# 37  2019-02-10 15:00:00  15.07
# 38  2019-02-10 18:00:00  13.88
# 39  2019-02-10 21:00:00  17.64

# %%
columns = ['time', 'temperature']
df = pd.DataFrame(abstracted_data, columns=columns)
df
# Out:
#                    time  temperature
# 0   2019-02-06 00:00:00        30.62
# 1   2019-02-06 03:00:00        31.88
# 2   2019-02-06 06:00:00        30.89
# 3   2019-02-06 09:00:00        22.13
# 4   2019-02-06 12:00:00        18.96
# 5   2019-02-06 15:00:00        19.02
# 6   2019-02-06 18:00:00        19.13
# 7   2019-02-06 21:00:00        19.18
# 8   2019-02-07 00:00:00        21.51
# 9   2019-02-07 03:00:00        20.68
# 10  2019-02-07 06:00:00        22.98
# 11  2019-02-07 09:00:00        20.86
# 12  2019-02-07 12:00:00        18.43
# 13  2019-02-07 15:00:00        17.12
# 14  2019-02-07 18:00:00        17.66
# 15  2019-02-07 21:00:00        16.50
# 16  2019-02-08 00:00:00        17.43
# 17  2019-02-08 03:00:00        18.18
# 18  2019-02-08 06:00:00        17.49
# 19  2019-02-08 09:00:00        16.83
# 20  2019-02-08 12:00:00        15.28
# 21  2019-02-08 15:00:00        13.50
# 22  2019-02-08 18:00:00        11.90
# 23  2019-02-08 21:00:00        11.98
# 24  2019-02-09 00:00:00        16.31
# 25  2019-02-09 03:00:00        19.33
# 26  2019-02-09 06:00:00        19.06
# 27  2019-02-09 09:00:00        18.46
# 28  2019-02-09 12:00:00        17.16
# 29  2019-02-09 15:00:00        14.27
# 30  2019-02-09 18:00:00        13.18
# 31  2019-02-09 21:00:00        14.64
# 32  2019-02-10 00:00:00        19.51
# 33  2019-02-10 03:00:00        21.99
# 34  2019-02-10 06:00:00        22.87
# 35  2019-02-10 09:00:00        21.07
# 36  2019-02-10 12:00:00        17.57
# 37  2019-02-10 15:00:00        15.07
# 38  2019-02-10 18:00:00        13.88
# 39  2019-02-10 21:00:00        17.64

# %%
# %matplotlib inline
import pandas as pd
# import matplotlib.pyplot as plt
df = pd.DataFrame(abstracted_data, columns=columns)
df.plot(figsize=(9, 4), x='time', rot=60)

# %% [markdown]
# # Summarising, Aggregating, and Grouping data

# %%
# Load csv using pandas.read_csv()
# Load excel using pandas.read_excel()

import pandas as pd
excel_file = 'xls_sample/sales.xlsx'
df = pd.read_excel(excel_file)
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 12   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 13   307599   Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 14   688981                   Keeling LLC     Wendy Yule  Fred Anderson
# 15   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
# 16   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 0           CPU         1   30000  presented
# 1      Software         1   10000  presented
# 2   Maintenance         2    5000    pending
# 3           CPU         1   35000   declined
# 4           CPU         2   65000        won
# 5           CPU         2   40000    pending
# 6      Software         1   10000  presented
# 7   Maintenance         2    5000    pending
# 8           CPU         1   35000   declined
# 9           CPU         2   65000        won
# 10          CPU         1   30000  presented
# 11  Maintenance         1    5000    pending
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won
# 15          CPU         2   65000   declined
# 16      Monitor         2    5000  presented

# %%
# how many rows in the data set
df['Account'].count()
# Out:
# 17

# %%
# What is the largest amount of price
df['Price'].max()
# Out:
# 100000

# %%
# Which row has the largest amount of price
dir(df['Price'].max())
df['Price'].idxmax()
# Out:
# 14

# %%
# How much is the total sales
df['Price'].sum()
# Out:
# 522000

# %%
# How much is manager Debra Henley's sales(Price colum)
# select sum(Price) from table 
# where 
#   Manger = 'Debra...' group by 'Manager'
df['Price'][df['Manager'] == 'Debra Henley'].sum()
# Out:
# 235000

# %%
# How many entries are for each representative.
df['Rep'].value_counts()
# Out:
# Cedric Moss      4
# Craig Booker     4
# Wendy Yule       4
# Daniel Hilton    3
# John Smith       2
# Name: Rep, dtype: int64

# %%
# How many of non-null unique client names.
df['Name'].nunique()
# Out:
# 12

# %%
# How many representatives.
df['Rep'].nunique()
# Out:
# 5

# %% [markdown]
# ### All other [basic statistics functions reference](http://pandas.pydata.org/pandas-docs/stable/getting_started/basics.html)

# %%
# %matplotlib inline
df.plot.bar(x='Rep', rot=60)

# %%
# Summarising Groups
# The groupby() function returns a GroupBy object, 
# but essentially describes how the rows of the original data set has been split.
df.groupby('Product').groups
# Out:
# {'CPU': Int64Index([0, 3, 4, 5, 8, 9, 10, 14, 15], dtype='int64'),
#  'Maintenance': Int64Index([2, 7, 11, 13], dtype='int64'),
#  'Monitor': Int64Index([16], dtype='int64'),
#  'Software': Int64Index([1, 6, 12], dtype='int64')}

# %%
# Get the first entry for each Product
df.groupby('Product').first()
# Out:
#              Account             Name           Rep        Manager  Quantity  \
# Product
# CPU           714466  Trantow-Barrows  Craig Booker   Debra Henley         1
# Maintenance   714466  Trantow-Barrows  Craig Booker   Debra Henley         2
# Monitor       729833        Koepp Ltd    Wendy Yule  Fred Anderson         2
# Software      714466  Trantow-Barrows  Craig Booker   Debra Henley         1
#
#              Price     Status
# Product
# CPU          30000  presented
# Maintenance   5000    pending
# Monitor       5000  presented
# Software     10000  presented

# %%
# Get the sum of sales per Product.
df.groupby('Product')['Price'].sum()
# Out:
# Product
# CPU            465000
# Maintenance     22000
# Monitor          5000
# Software        30000
# Name: Price, dtype: int64

# %%
# Get the sum of sales per sales representative.
df.groupby('Rep')['Price'].sum()
# Out:
# Rep
# Cedric Moss      110000
# Craig Booker      80000
# Daniel Hilton    115000
# John Smith        40000
# Wendy Yule       177000
# Name: Price, dtype: int64

# %%
# What is the sum of sales for CPU for each representative.
df[df['Product'] == 'CPU'].groupby('Rep')['Price'].sum()
# Out:
# Rep
# Cedric Moss       95000
# Craig Booker      65000
# Daniel Hilton    105000
# John Smith        35000
# Wendy Yule       165000
# Name: Price, dtype: int64

# %% [markdown]
# You can also group by more than one variable, allowing more complex queries.

# %%
# List representative's sales by manager.
df.groupby(['Manager', 'Rep'])['Price'].sum()
# Out:
# Manager        Rep
# Debra Henley   Craig Booker      80000
#                Daniel Hilton    115000
#                John Smith        40000
# Fred Anderson  Cedric Moss      110000
#                Wendy Yule       177000
# Name: Price, dtype: int64

# %% [markdown]
# Functions like max(), min(), mean(), first(), last() can be quickly applied to the GroupBy object to obtain summary statistics for each group

# %%
# List representative's sales per client.
df.groupby(['Manager', 'Rep', 'Name'])['Price'].sum()
# Out:
# Manager        Rep            Name
# Debra Henley   Craig Booker   Fritsch, Russel and Anderson     35000
#                               Trantow-Barrows                  45000
#                Daniel Hilton  Kiehn-Spinka                     65000
#                               Kulas Inc                        50000
#                John Smith     Barton LLC                       35000
#                               Jerde-Hilpert                     5000
# Fred Anderson  Cedric Moss    Herman LLC                       65000
#                               Purdy-Kunde                      30000
#                               Stokes LLC                       15000
#                Wendy Yule     Kassulke, Ondricka and Metz       7000
#                               Keeling LLC                     100000
#                               Koepp Ltd                        70000
# Name: Price, dtype: int64

# %% [markdown]
# ### Multiple Statistics per Group
# agg() function
#
# Instructions for aggregation are provided in the form of a python dictionary or list.
#
# The dictionary keys are used to specify the columns upon which you’d like to perform operations, and the dictionary values to specify the function to run.

# %%
df.groupby(['Manager', 'Rep', 'Product']).agg(
    {'Price': 'sum',     # find the sum of the Price for each group
     'Name': 'count',    # find the number of clients
     'Status': 'first'   # get the first status per group
    })
# Out:
#                                           Price  Name     Status
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000     2  presented
#                             Maintenance    5000     1    pending
#                             Software      10000     1  presented
#               Daniel Hilton CPU          105000     2        won
#                             Software      10000     1  presented
#               John Smith    CPU           35000     1   declined
#                             Maintenance    5000     1    pending
# Fred Anderson Cedric Moss   CPU           95000     2        won
#                             Maintenance    5000     1    pending
#                             Software      10000     1  presented
#               Wendy Yule    CPU          165000     2        won
#                             Maintenance    7000     1        won
#                             Monitor        5000     1  presented

# %%
# Applying multiple functions to columns in groups
df.groupby(['Manager', 'Rep', 'Product']).agg(
    {'Price': 'sum',     # find the sum of the Price for each group
     'Name': 'count',    # find the number of clients
     'Status': ['first', 'last']   # get the first status per group
    })
# Out:
#                                           Price  Name     Status
#                                             sum count      first       last
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000     2  presented   declined
#                             Maintenance    5000     1    pending    pending
#                             Software      10000     1  presented  presented
#               Daniel Hilton CPU          105000     2        won    pending
#                             Software      10000     1  presented  presented
#               John Smith    CPU           35000     1   declined   declined
#                             Maintenance    5000     1    pending    pending
# Fred Anderson Cedric Moss   CPU           95000     2        won  presented
#                             Maintenance    5000     1    pending    pending
#                             Software      10000     1  presented  presented
#               Wendy Yule    CPU          165000     2        won   declined
#                             Maintenance    7000     1        won        won
#                             Monitor        5000     1  presented  presented
