# %% [markdown]
# Format of csv sample file: csv_sample/australian_postcodes.csv
# Data Fields
# The files have eight fields in each:
#
#     postcode	The postcode in numerical format - 0000 to 9999
#     locality	The locality of the postcode - typically the city/suburb or postal distribution centre
#     state	    The Australian state in which the locality is situated
#     long	    The longitude of the locality - defaults to 0 when not available
#     lat	        The latitude of the locality - defaults to 0 when not available
#     dc1	        The Australia Post distribution Centre servicing this postcode - defaults to blank when not available
#     type1	    The of locality, such as a delivery area, post office or a "Large Volume Recipient" such as a GPO,
#                 defaults to blank when not available
#     status	    A note indicating whether the data is new, removed or updated - new column Nov 2018

# %%
# Reading a csv file.

import csv

csv_file = 'csv_sample/australian_postcodes.csv'
with open(csv_file, newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    for index, cells in enumerate(reader):
        print(', '.join(cells))
        if index > 10:
            break
# Out:
# <class 'list'>
# ﻿postcode, locality, State, long, lat, dc, type, status
# <class 'list'>
# 6532, CARRARANG, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, COBURN, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, COOLCALALAYA, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, DARTMOOR, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, DEEPDALE, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, DINDILOA, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, DRUMMOND COVE, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, DURAWAH, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# 6532, EAST CHAPMAN, WA, 115.004595, -28.440886, GERALDTON DC, Delivery Area,
# <class 'list'>
# ...

# %%
import csv
csv_file = 'csv_sample/australian_postcodes.csv'
with open(csv_file, newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    for index, cells in enumerate(reader):
        if cells[2] == 'VIC':
            print(cells)
# Out:
# ['8001', 'MELBOURNE', 'VIC', '0', '0', 'CITY MAIL PROCESSING CENTRE', 'Post Office Boxes', '']
# ['8002', 'EAST MELBOURNE', 'VIC', '0', '0', 'EAST MELBOURNE RP', 'Post Office Boxes', '']
# ['8003', 'COLLINS STREET EAST', 'VIC', '0', '0', '', '', '']
# ['8004', 'ST KILDA ROAD', 'VIC', '0', '0', 'ST KILDA ROAD RP', 'Post Office Boxes', '']
# ['8005', 'WORLD TRADE CENTRE', 'VIC', '0', '0', 'WORLD TRADE CENTRE', 'Post Office Boxes', '']
# ['8006', 'ABECKETT STREET', 'VIC', '0', '0', "MELBOURNE A'BECKETT STREET", 'Post Office Boxes', '']
# ['8007', 'COLLINS STREET WEST', 'VIC', '0', '0', '', '', '']
# ['8008', 'ST KILDA ROAD CENTRAL', 'VIC', '0', '0', '', '', '']
# ['8009', 'FLINDERS LANE', 'VIC', '0', '0', 'MELBOURNE FLINDERS LANE', 'Post Office Boxes', '']
# ['8010', 'LAW COURTS', 'VIC', '0', '0', 'MELBOURNE LAW COURTS RP', 'Post Office Boxes', '']
# ['8045', 'MELBOURNE', 'VIC', '0', '0', 'MELBOURNE GPO', 'LVR', '']
# ['8051', 'MELBOURNE', 'VIC', '0', '0', 'MELBOURNE GPO', 'LVR', '']
# ...

# %%
# Writing a csv file.
import csv
with open('csv_sample/temp.csv', 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(['Spam'] * 5 + ['Baked Beans'])
    spamwriter.writerow(['Spam', 'Lovely Spam', '"Wonderful Spam"'])

# %%
# Let read this file as text file to see whether the content has changed.
# Change 'delimiter', quotechar in above program, then rerun this cell to see what's changed.
with open('csv_sample/temp.csv') as csvfile:
    print(csvfile.read())
# Out:
# Spam,Spam,Spam,Spam,Spam,Baked Beans
# Spam,Lovely Spam,"""Wonderful Spam"""

# %% [markdown]
# [csv module](https://docs.python.org/3/library/csv.html)
# [Australian postcodes downloadable](https://www.matthewproctor.com/australian_postcodes)
